# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv("Building_and_Safety_Permit_Information.csv",low_memory=False)

# %%
df.head()
# Out:
#   Assessor Book Assessor Page Assessor Parcel                Tract Block Lot  \
# 0          4117           006             001              TR 8557    35   1
# 1          2602           019             042             TR 21545   NaN  18
# 2          2565           008             069              TR 3971   NaN   1
# 3          2233           010             004             TR 10869   NaN   1
# 4          4314           005             009  BRUNDAGE PALM PLACE   NaN  14
#
#   Reference # (Old Permit #)      PCIS Permit #          Status Status Date  \
# 0                  17LA76150  16010-10002-00098  Permit Finaled  09/29/2017
# 1                        NaN  13042-20000-11279  Permit Finaled  07/11/2013
# 2                  17VN37597  16030-20000-06797  Permit Finaled  12/07/2017
# 3                  14VN74792  14016-20000-07197  Permit Finaled  04/23/2014
# 4                        NaN  17042-90000-00040  Permit Finaled  01/27/2017
#
#             ...           Applicant Address 1 Applicant Address 2  \
# 0           ...               5117 MACAFEE RD                 NaN
# 1           ...                           NaN                 NaN
# 2           ...                           NaN                 NaN
# 3           ...                           NaN                 NaN
# 4           ...            1045 N GENESEE AVE                 NaN
#
#   Applicant Address 3         Zone Occupancy  \
# 0        TORRANCE, CA         R1-1       NaN
# 1                 NaN  RE11-1-HPOZ       NaN
# 2                 NaN     R1-1-RFA       NaN
# 3                 NaN      [Q]R3-1       NaN
# 4     LOS ANGELES, CA         R3-1       NaN
#
#   Floor Area-L.A. Building Code Definition Census Tract  Council District  \
# 0                                      NaN      2781.02              11.0
# 1                                      0.0      1066.41              12.0
# 2                                      0.0      1011.10               7.0
# 3                                      NaN      1276.06               6.0
# 4                                      0.0      2699.05               5.0
#
#        Latitude/Longitude  Applicant Relationship
# 0  (33.95333, -118.44446)               Architect
# 1  (34.30261, -118.50319)              Owner-Bldr
# 2  (34.25721, -118.28711)              Contractor
# 3   (34.19338, -118.4791)              Contractor
# 4  (34.02206, -118.40349)           Net Applicant
#
# [5 rows x 56 columns]

# %%
# Exploration, construction types
df["Permit Type"].value_counts().head(10).plot(kind="bar")
plt.show()

# %%
df["Zip Code"]=df["Zip Code"].fillna(0).astype(int)
df["Zip Code"].value_counts().head(10).plot(kind="bar")
plt.show()

# %%
fig, [ax1,ax2,ax3,ax4] = plt.subplots(ncols=4)

df[df["Zip Code"]==90045]["Permit Type"].value_counts().head(6).plot(kind="pie",ax=ax1,title="90045 - airport")
df[df["Zip Code"]==90049]["Permit Type"].value_counts().head(6).plot(kind="pie",ax=ax2,title="90049 - brentwood")
df[df["Zip Code"]==91331]["Permit Type"].value_counts().head(6).plot(kind="pie",ax=ax3,title="91331 - Pacoima")
df[df["Zip Code"]==91367]["Permit Type"].value_counts().head(6).plot(kind="pie",ax=ax4,title="91367 - Woodland Hills")

ax1.set_ylabel('')
ax2.set_ylabel('')
ax3.set_ylabel('')
ax4.set_ylabel('')
ax1.set_aspect(1)
ax2.set_aspect(1)
ax3.set_aspect(1)
ax4.set_aspect(1)
plt.subplots_adjust(right=3)

# %%
rent=pd.read_csv("LA_rent_index.csv")
rent.head()
# Out:
#   Los Angeles, CA Zillow Rent Index - All Homes    Unnamed: 1 Unnamed: 2  \
# 0                                   Region Name   Region Type  Data Type
# 1                                   Los Angeles          city  All Homes
# 2                                        Arleta  neighborhood  All Homes
# 3                               Atwater Village  neighborhood  All Homes
# 4                                       Bel Air  neighborhood  All Homes
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0   Nov 2010   Dec 2010   Jan 2011   Feb 2011   Mar 2011   Apr 2011
# 1     $2,270     $2,257     $2,254     $2,253     $2,250     $2,251
# 2     $1,998     $1,998     $1,999     $2,000     $2,000     $1,997
# 3     $2,328     $2,336     $2,329     $2,318     $2,314     $2,311
# 4     $8,710     $8,738     $8,751     $8,743     $8,731     $8,720
#
#   Unnamed: 9     ...      Unnamed: 91 Unnamed: 92 Unnamed: 93 Unnamed: 94  \
# 0   May 2011     ...         Mar 2018    Apr 2018    May 2018    Jun 2018
# 1     $2,253     ...           $2,960      $2,970      $2,977      $2,980
# 2     $1,998     ...           $2,579      $2,612      $2,640      $2,648
# 3     $2,309     ...           $3,065      $3,027      $2,999      $2,989
# 4     $8,719     ...          $12,027     $12,072     $12,113     $12,118
#
#   Unnamed: 95 Unnamed: 96 Unnamed: 97 Unnamed: 98 Unnamed: 99 Unnamed: 100
# 0    Jul 2018    Aug 2018    Sep 2018    Oct 2018    Nov 2018     Dec 2018
# 1      $2,980      $2,979      $2,979      $2,985      $3,010       $3,043
# 2      $2,649      $2,651      $2,658      $2,669      $2,698       $2,730
# 3      $2,988      $2,987      $2,991      $3,004      $3,075       $3,158
# 4     $12,124     $12,124     $12,117     $12,124     $12,274      $12,502
#
# [5 rows x 101 columns]

# %%
#Rent index for LA
LA_rent_train=[]
for i in range(29,101):
    LA_rent_train.append(int(''.join(c for c in rent.iloc[1][i] if c.isdigit())))

# %%
df['Issue Date']=pd.to_datetime(df['Issue Date'])

# %%
permit_type=df["Permit Type"].unique()
permit_train=[]

for year in range(2013,2019):
    for month in range(1,13):
        if month!=12:
            temp=df[(df['Issue Date']>=datetime(year,month,1)) & (df['Issue Date']<datetime(year,month+1,1))]["Permit Type"].value_counts()
        else:
            temp=df[(df['Issue Date']>=datetime(year,month,1)) & (df['Issue Date']<datetime(year+1,1,1))]["Permit Type"].value_counts()
        row=[]
        for permit in permit_type:
            if permit in temp:
                row.append(temp[permit])
            else:
                row.append(0)
        permit_train.append(row)
        
temp=df[(df['Issue Date']>=datetime(2019,1,1)) & (df['Issue Date']<datetime(2019,2,1))]["Permit Type"].value_counts()
permit_JAN2019=[]
for permit in permit_type:
    if permit in temp:
        permit_JAN2019.append(temp[permit])
    else:
        permit_JAN2019.append(0)

# %%
reg = LinearRegression().fit(permit_train, LA_rent_train)
reg.score(permit_train, LA_rent_train)
# Out:
# 0.8813376560385475

# %%
print ("Predicted JAN 2019 LA rent index: {:.0f}".format(*reg.predict([permit_JAN2019])))
# Out:
# Predicted JAN 2019 LA rent index: 3062

# %%
index=LA_rent.copy()
index.append(3062)
fig, ax = plt.subplots()
fig=plt.plot(index)
plt.xticks(range(0,73,12), ['2013', '2014', '2015', '2016', '2017' , '2018' , '2019'])
ax.set_xlabel('year')
ax.set_ylabel('LA rent index')
plt.show()

# %%
year=[2013,2014,2015,2016,2017,2018]
brentwood=[]
brentwood.append(len(df[(df['Issue Date'].str.contains('2013')) & (df["Zip Code"]==90049)]))
brentwood.append(len(df[(df['Issue Date'].str.contains('2014')) & (df["Zip Code"]==90049)]))
brentwood.append(len(df[(df['Issue Date'].str.contains('2015')) & (df["Zip Code"]==90049)]))
brentwood.append(len(df[(df['Issue Date'].str.contains('2016')) & (df["Zip Code"]==90049)]))
brentwood.append(len(df[(df['Issue Date'].str.contains('2017')) & (df["Zip Code"]==90049)]))
brentwood.append(len(df[(df['Issue Date'].str.contains('2018')) & (df["Zip Code"]==90049)]))
fig, ax = plt.subplots()
ax.set_xlabel('year')
ax.set_ylabel('number of permit')
plt.plot(year,brentwood)

# %%
fig, [[ax1,ax2,ax3],[ax4,ax5,ax6]] = plt.subplots(2,3)

df[(df["Zip Code"]==90049) & (df['Issue Date'].str.contains('2013'))]["Permit Type"].value_counts().head(6).plot(kind="pie",ax=ax1,title="year 2013")
df[(df["Zip Code"]==90049) & (df['Issue Date'].str.contains('2014'))]["Permit Type"].value_counts().head(6).plot(kind="pie",ax=ax2,title="year 2014")
df[(df["Zip Code"]==90049) & (df['Issue Date'].str.contains('2015'))]["Permit Type"].value_counts().head(6).plot(kind="pie",ax=ax3,title="year 2015")
df[(df["Zip Code"]==90049) & (df['Issue Date'].str.contains('2016'))]["Permit Type"].value_counts().head(6).plot(kind="pie",ax=ax4,title="year 2016")
df[(df["Zip Code"]==90049) & (df['Issue Date'].str.contains('2017'))]["Permit Type"].value_counts().head(6).plot(kind="pie",ax=ax5,title="year 2017")
df[(df["Zip Code"]==90049) & (df['Issue Date'].str.contains('2018'))]["Permit Type"].value_counts().head(6).plot(kind="pie",ax=ax6,title="year 2018")

ax1.set_ylabel('')
ax2.set_ylabel('')
ax3.set_ylabel('')
ax4.set_ylabel('')
ax5.set_ylabel('')
ax6.set_ylabel('')
ax1.set_aspect(1)
ax2.set_aspect(1)
ax3.set_aspect(1)
ax4.set_aspect(1)
ax5.set_aspect(1)
ax6.set_aspect(1)
plt.subplots_adjust(right=2)

# %%
pop=[55021,56978,58905,60688,62433]
growth=[1429,1957,1927,1783,1745]
growthrate=[2.67,3.56,3.38,3.03,2.88]

items=["Electrical","Bldg-Alter/Repair","Plumbing","HVAC","Grading"]
X=[]
for year in range(2013,2018):
    sub=[]
    for item in items:
        subdf=df[(df["Zip Code"]==90049) & (df['Issue Date'].str.contains(str(year))) & (df['Permit Type']==item)]
        sub.append(len(subdf))
    X.append(sub)

# %%
reg = LinearRegression().fit(X, growthrate)
print (reg.intercept_,reg.coef_)
print ("{:.6f}".format(reg.score(X, growthrate)))
# Out:
# (-0.161267110730289, array([-0.00249966, -0.0066886 ,  0.01024016, -0.00264838,  0.01425043]))
# 1.000000

# %%
items=["Electrical","Bldg-Alter/Repair","Plumbing","HVAC","Grading"]
X_2018=[]
year=2018
sub=[]
for item in items:
    subdf=df[(df["Zip Code"]==90049) & (df['Issue Date'].str.contains(str(year))) & (df['Permit Type']==item)]
    sub.append(len(subdf))
X_2018.append(sub)

# %%
pop2018=reg.predict(X_2018)
year=[2013,2014,2015,2016,2017,2018]
growthrate=[2.67,3.56,3.38,3.03,2.88]
growthrate.append(pop2018)
fig, ax = plt.subplots()
ax.set_xlabel('year')
ax.set_ylabel('population growth rate')
ax.set_title("Predicted Brentwood population growth rate in 2018: {:.2f}%".format(float(pop2018)))
plt.plot(year,growthrate)
# Out:
# Predicted Brentwood population growth rate in 2018: 0.66%
